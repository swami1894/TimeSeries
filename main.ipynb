# %%
import numpy as np
import pandas as pd
import sklearn.model_selection as selection
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# %%
dataFrame = pd.read_csv("./data/Electric_Production.csv")

# %%
dataFrame.head()
# Out:
#        DATE  IPG2211A2N
# 0  1/1/1985     72.5052
# 1  2/1/1985     70.6720
# 2  3/1/1985     62.4502
# 3  4/1/1985     57.4714
# 4  5/1/1985     55.3151

# %%
dataFrame.dtypes
# Out:
# DATE           object
# IPG2211A2N    float64
# dtype: object

# %%
dataFrame.DATE = pd.to_datetime(dataFrame["DATE"])

# %%
dataFrame.dtypes
# Out:
# DATE          datetime64[ns]
# IPG2211A2N           float64
# dtype: object

# %%
dataFrame.head()
# Out:
#         DATE  IPG2211A2N
# 0 1985-01-01     72.5052
# 1 1985-02-01     70.6720
# 2 1985-03-01     62.4502
# 3 1985-04-01     57.4714
# 4 1985-05-01     55.3151

# %%
plt.plot(dataFrame["DATE"], dataFrame["IPG2211A2N"])
plt.show()
